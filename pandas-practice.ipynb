# %%
import pandas as pd

# %%
colours = pd.Series(['Blue', 'Brown', 'Red'])
colours
# Out:
# 0     Blue
# 1    Brown
# 2      Red
# dtype: object

# %%
cars = pd.Series(['BMW', 'Audi', 'Mercedes'])
cars
# Out:
# 0         BMW
# 1        Audi
# 2    Mercedes
# dtype: object

# %%
df = pd.DataFrame({'Car make': cars, 'Colour': colours})
df
# Out:
#    Car make Colour
# 0       BMW   Blue
# 1      Audi  Brown
# 2  Mercedes    Red

# %%
car_sales = pd.read_csv('Resources/car-sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv('practice-car-sales.csv')

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
num = pd.Series([32, 413, 5903, 1231231, 23, 0.0003, 15])
num.mean()
# Out:
# 176802.42861428572

# %%
num.sum()
# Out:
# 1237617.0003

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
car_sales['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales['Odometer (KM)'].mean()
# Out:
# 78601.4

# %%
car_sales[car_sales['Odometer (KM)'] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales['Make'], car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
car_sales['Odometer (KM)'].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]', '').astype(int)
# Out:
# <ipython-input-41-5d08bb8955e2>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales['Price'] = car_sales['Price'].str.replace('[\$\,\.]', '').astype(int)

# %%
car_sales['Price'] = car_sales['Price'] / 100
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales['Price'].dtype
# Out:
# dtype('float64')

# %%
car_sales['Make'] = car_sales['Make'].str.lower()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_missing = pd.read_csv('Resources/car-sales-missing-data.csv')
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(),
                                    inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing = car_sales_missing.dropna()

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales['Seats'] = 5

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0      5
# 1   honda    Red          87899      4   5000.0      5
# 2  toyota   Blue          32549      3   7000.0      5
# 3     bmw  Black          11179      5  22000.0      5
# 4  nissan  White         213095      4   3500.0      5
# 5  toyota  Green          99213      4   4500.0      5
# 6   honda   Blue          45698      4   7500.0      5
# 7   honda   Blue          54738      4   7000.0      5
# 8  toyota  White          60000      4   6250.0      5
# 9  nissan  White          31600      4   9700.0      5

# %%
engine = [1.3, 1.4, 2.8, 4.0, 1.6, 3.5, 1.8, 2.9, 4.5, 4.0]
car_sales['Engine size'] = engine

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Engine size
# 0  toyota  White         150043      4   4000.0      5          1.3
# 1   honda    Red          87899      4   5000.0      5          1.4
# 2  toyota   Blue          32549      3   7000.0      5          2.8
# 3     bmw  Black          11179      5  22000.0      5          4.0
# 4  nissan  White         213095      4   3500.0      5          1.6
# 5  toyota  Green          99213      4   4500.0      5          3.5
# 6   honda   Blue          45698      4   7500.0      5          1.8
# 7   honda   Blue          54738      4   7000.0      5          2.9
# 8  toyota  White          60000      4   6250.0      5          4.5
# 9  nissan  White          31600      4   9700.0      5          4.0

# %%
car_sales['Price per km'] = car_sales['Price'] / car_sales['Odometer (KM)']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Engine size  \
# 0  toyota  White         150043      4   4000.0      5          1.3
# 1   honda    Red          87899      4   5000.0      5          1.4
# 2  toyota   Blue          32549      3   7000.0      5          2.8
# 3     bmw  Black          11179      5  22000.0      5          4.0
# 4  nissan  White         213095      4   3500.0      5          1.6
# 5  toyota  Green          99213      4   4500.0      5          3.5
# 6   honda   Blue          45698      4   7500.0      5          1.8
# 7   honda   Blue          54738      4   7000.0      5          2.9
# 8  toyota  White          60000      4   6250.0      5          4.5
# 9  nissan  White          31600      4   9700.0      5          4.0
#
#    Price per km
# 0      0.026659
# 1      0.056883
# 2      0.215060
# 3      1.967976
# 4      0.016425
# 5      0.045357
# 6      0.164121
# 7      0.127882
# 8      0.104167
# 9      0.306962

# %%
car_sales.drop('Price per km', axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Engine size
# 0  toyota  White         150043      4   4000.0      5          1.3
# 1   honda    Red          87899      4   5000.0      5          1.4
# 2  toyota   Blue          32549      3   7000.0      5          2.8
# 3     bmw  Black          11179      5  22000.0      5          4.0
# 4  nissan  White         213095      4   3500.0      5          1.6
# 5  toyota  Green          99213      4   4500.0      5          3.5
# 6   honda   Blue          45698      4   7500.0      5          1.8
# 7   honda   Blue          54738      4   7000.0      5          2.9
# 8  toyota  White          60000      4   6250.0      5          4.5
# 9  nissan  White          31600      4   9700.0      5          4.0

# %%
car_sales.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Engine size  \
# 4  nissan  White         213095      4   3500.0      5          1.6
# 8  toyota  White          60000      4   6250.0      5          4.5
# 2  toyota   Blue          32549      3   7000.0      5          2.8
# 3     bmw  Black          11179      5  22000.0      5          4.0
# 6   honda   Blue          45698      4   7500.0      5          1.8
# 7   honda   Blue          54738      4   7000.0      5          2.9
# 5  toyota  Green          99213      4   4500.0      5          3.5
# 0  toyota  White         150043      4   4000.0      5          1.3
# 1   honda    Red          87899      4   5000.0      5          1.4
# 9  nissan  White          31600      4   9700.0      5          4.0
#
#    Price per km
# 4      0.016425
# 8      0.104167
# 2      0.215060
# 3      1.967976
# 6      0.164121
# 7      0.127882
# 5      0.045357
# 0      0.026659
# 1      0.056883
# 9      0.306962

# %%
car_sales_shuffled = car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Engine size  \
# 2  toyota   Blue          32549      3   7000.0      5          2.8
# 6   honda   Blue          45698      4   7500.0      5          1.8
# 1   honda    Red          87899      4   5000.0      5          1.4
# 9  nissan  White          31600      4   9700.0      5          4.0
# 3     bmw  Black          11179      5  22000.0      5          4.0
# 4  nissan  White         213095      4   3500.0      5          1.6
# 5  toyota  Green          99213      4   4500.0      5          3.5
# 0  toyota  White         150043      4   4000.0      5          1.3
# 7   honda   Blue          54738      4   7000.0      5          2.9
# 8  toyota  White          60000      4   6250.0      5          4.5
#
#    Price per km
# 2      0.215060
# 6      0.164121
# 1      0.056883
# 9      0.306962
# 3      1.967976
# 4      0.016425
# 5      0.045357
# 0      0.026659
# 7      0.127882
# 8      0.104167

# %%
car_sales_shuffled.reset_index(drop=True)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Engine size  \
# 0  toyota   Blue          32549      3   7000.0      5          2.8
# 1   honda   Blue          45698      4   7500.0      5          1.8
# 2   honda    Red          87899      4   5000.0      5          1.4
# 3  nissan  White          31600      4   9700.0      5          4.0
# 4     bmw  Black          11179      5  22000.0      5          4.0
# 5  nissan  White         213095      4   3500.0      5          1.6
# 6  toyota  Green          99213      4   4500.0      5          3.5
# 7  toyota  White         150043      4   4000.0      5          1.3
# 8   honda   Blue          54738      4   7000.0      5          2.9
# 9  toyota  White          60000      4   6250.0      5          4.5
#
#    Price per km
# 0      0.215060
# 1      0.164121
# 2      0.056883
# 3      0.306962
# 4      1.967976
# 5      0.016425
# 6      0.045357
# 7      0.026659
# 8      0.127882
# 9      0.104167

# %%
car_sales['Odometer (KM)'] = car_sales['Odometer (KM)'].apply(lambda x: 1/6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Engine size  \
# 0  toyota  White       0.166667      4   4000.0      5          1.3
# 1   honda    Red       0.166667      4   5000.0      5          1.4
# 2  toyota   Blue       0.166667      3   7000.0      5          2.8
# 3     bmw  Black       0.166667      5  22000.0      5          4.0
# 4  nissan  White       0.166667      4   3500.0      5          1.6
# 5  toyota  Green       0.166667      4   4500.0      5          3.5
# 6   honda   Blue       0.166667      4   7500.0      5          1.8
# 7   honda   Blue       0.166667      4   7000.0      5          2.9
# 8  toyota  White       0.166667      4   6250.0      5          4.5
# 9  nissan  White       0.166667      4   9700.0      5          4.0
#
#    Price per km
# 0      0.026659
# 1      0.056883
# 2      0.215060
# 3      1.967976
# 4      0.016425
# 5      0.045357
# 6      0.164121
# 7      0.127882
# 8      0.104167
# 9      0.306962

# %%
car_sales = car_sales.rename(columns={'Odometer (KM)': 'Odometer (MI)'})
car_sales
# Out:
#      Make Colour  Odometer (MI)  Doors    Price  Seats  Engine size  \
# 0  toyota  White       0.166667      4   4000.0      5          1.3
# 1   honda    Red       0.166667      4   5000.0      5          1.4
# 2  toyota   Blue       0.166667      3   7000.0      5          2.8
# 3     bmw  Black       0.166667      5  22000.0      5          4.0
# 4  nissan  White       0.166667      4   3500.0      5          1.6
# 5  toyota  Green       0.166667      4   4500.0      5          3.5
# 6   honda   Blue       0.166667      4   7500.0      5          1.8
# 7   honda   Blue       0.166667      4   7000.0      5          2.9
# 8  toyota  White       0.166667      4   6250.0      5          4.5
# 9  nissan  White       0.166667      4   9700.0      5          4.0
#
#    Price per km
# 0      0.026659
# 1      0.056883
# 2      0.215060
# 3      1.967976
# 4      0.016425
# 5      0.045357
# 6      0.164121
# 7      0.127882
# 8      0.104167
# 9      0.306962
